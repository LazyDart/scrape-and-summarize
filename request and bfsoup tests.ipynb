# %%
import bs4  # Scraping HTML
import requests  # Making Requests to a websites

import pandas as pd # Data Wrangling
import numpy as np # Math
import re # Regex

# %%
# Make a Request to a healthcare and pharmaceuticals subsite of Reuters
request = requests.get("https://www.reuters.com/business/healthcare-pharmaceuticals/")

# %%
# Parse Healthcare Subsite of Reuters
soup = bs4.BeautifulSoup(request.text, 'html.parser')

# %%
# Find all html parts containing links
anchor = soup.find_all("a")

# %%
# Print all extracted Links found on website
for attr in anchor:
    print(attr["href"])
# Out:
# #main-content
# /differentiator/
# /
# /world/
# /business/
# /markets/
# /sustainability/
# /legal/
# /breakingviews/
# /technology/
# https://www.reuters.com/investigates/
# /account/register/sign-up/&journeyStart=navigation
# /business/healthcare-pharmaceuticals/novo-nordisk-invest-6-bln-denmark-expansions-2023-11-10/
# /tags/government-health-policy/
# /business/healthcare-pharmaceuticals/novo-nordisk-invest-6-bln-denmark-expansions-2023-11-10/
# /business/healthcare-pharmaceuticals/
# /business/healthcare-pharmaceuticals/surgeons-new-york-announce-worlds-first-eye-transplant-2023-11-09/
# /business/healthcare-pharmaceuticals/surgeons-new-york-announce-worlds-first-eye-transplant-2023-11-09/
# /tags/regulatory-oversight/
# /business/healthcare-pharmaceuticals/eu-regulator-backs-eli-lillys-mounjaro-weight-management-2023-11-10/
# /business/healthcare-pharmaceuticals/eu-regulator-backs-eli-lillys-mounjaro-weight-management-2023-11-10/
# /tags/mergers-acquisitions/
# /business/healthcare-pharmaceuticals/drugmaker-novo-nordisk-seeks-obesity-diabetes-bolt-on-deals-2023-11-10/
# /business/healthcare-pharmaceuticals/drugmaker-novo-nordisk-seeks-obesity-diabetes-bolt-on-deals-2023-11-10/
# /tags/regulatory-oversight/
# /business/healthcare-pharmaceuticals/fda-approves-valnevas-chikungunya-vaccine-adults-2023-11-10/
# /business/healthcare-pharmaceuticals/fda-approves-valnevas-chikungunya-vaccine-adults-2023-11-10/
# /world/
# /world/us/unpublished-study-finds-elevated-cancer-rates-us-military-base-2023-11-10/
# /world/us/unpublished-study-finds-elevated-cancer-rates-us-military-base-2023-11-10/
# /sustainability/boards-policy-regulation/
# /business/healthcare-pharmaceuticals/weight-loss-drugs-transforming-healthcare-may-help-with-addiction-reuters-events-2023-11-09/
# /business/healthcare-pharmaceuticals/weight-loss-drugs-transforming-healthcare-may-help-with-addiction-reuters-events-2023-11-09/
# #
# https://www.reuters.com/business/healthcare-pharmaceuticals/healthcare-companies-counter-investor-worries-over-wegovy-effect-2023-10-27/
# https://www.reuters.com/business/healthcare-pharmaceuticals/blood-tests-needed-widespread-alzheimers-diagnosis-way-2023-10-11/
# https://www.reuters.com/business/healthcare-pharmaceuticals/down-syndrome-families-fight-access-alzheimers-trials-treatments-2023-10-10/
# /business/healthcare-pharmaceuticals/us-fda-approves-valnevas-chikungunya-vaccine-2023-11-09/
# /business/healthcare-pharmaceuticals/
# /business/healthcare-pharmaceuticals/us-fda-approves-valnevas-chikungunya-vaccine-2023-11-09/
# /world/
# /business/
# /markets/
# /sustainability/
# /legal/
# /breakingviews/
# /technology/
# /investigates/
# /sports/
# /science/
# /lifestyle/
# https://www.reutersagency.com/en/about/about-us/
# https://www.thomsonreuters.com/en/careers.html
# https://www.reutersagency.com/en/?utm_source=website&utm_medium=reuters&utm_campaign=site-referral&utm_content=us&utm_term=0
# https://www.reutersagency.com/en/brand-attribution-guidelines/
# https://www.reutersagency.com/en/about/leadership-team/
# /fact-check/
# https://static.reuters.com/resources/media/editorial/20210405/DiversityReportApril2021.pdf
# https://www.reuters.com/tools/mobile/us
# https://reuters.com/newsletters/
# https://www.twitter.com/Reuters
# https://www.facebook.com/Reuters
# https://www.instagram.com/Reuters
# https://www.youtube.com/user/ReutersVideo
# https://www.linkedin.com/company/10256858/
# https://legal.thomsonreuters.com/en/products/westlaw
# https://tax.thomsonreuters.com/en/onesource
# https://tax.thomsonreuters.com/en/checkpoint
#  https://www.refinitiv.com/en/products/refinitiv-workspace/?utm_source=reuters.com&utm_medium=footer&utm_campaign=Reuters_ProductPage_Links
#  https://www.refinitiv.com/en/financial-data/?utm_source=reuters.com&utm_medium=footer&utm_campaign=Reuters_DataCatalogPage_Links
# https://www.refinitiv.com/en/products/world-check-kyc-screening/?utm_source=reuters.com&utm_medium=footer&utm_campaign=Reuters_ProductPage_Links
# https://www.reutersagency.com/en/services/advertising-solutions/
# /info-pages/advertising-guidelines/
# https://www.reuters.com/coupons/
# https://www.reutersagency.com/en/licensereuterscontent/?utm_medium=rcom-footer&utm_campaign=rcom-rcp-lead
# https://www.thomsonreuters.com/en/privacy-statement.html#cookies
# /info-pages/terms-of-use/
# https://www.thomsonreuters.com/en/privacy-statement.html
# https://www.thomsonreuters.com/en/policies/digital-accessibility-policy.html
# /info-pages/contact-us/
# https://trdigital.iad1.qualtrics.com/jfe/form/SV_8kte8gArGyCGVhz
# https://www.reuters.com/info-pages/disclaimer/
# https://www.thomsonreuters.com/en/policies/copyright.html

# %%
# Get only links to articles about novo nordisk company
novo_news = [attr["href"] for attr in anchor if "novo" in attr["href"]]

# %%
all_article_paragraphs = []

for article in novo_news:
    # Make a Request Append Https Reuters string for proper url format.
    request1 = requests.get("https://www.reuters.com" + article)
    
    # Parse HTML
    soup_subsite = bs4.BeautifulSoup(request1.text, "html.parser")
    
    # Seek All Paragraphs
    paragraphs = soup_subsite.find_all("p")
    
    # Delete html stuff
    # extracted_text = [re.sub("<[^>]+>", "", str(paragraph)) for paragraph in paragraphs]
    extracted_text = [paragraph.text for paragraph in paragraphs]
    

    # Append to a list of all articles
    all_article_paragraphs.append(extracted_text)
